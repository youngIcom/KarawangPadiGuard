# %%
"""
Training Script for Rice Disease Detection (Computer Vision)
KarawangPadiGuard - Microsoft Elevate Datathon

Author: Yesaya Situmorang
Date: 2026-04-28
"""

import os
import json
import numpy as np
from pathlib import Path
from datetime import datetime
from typing import List, Tuple

# Deep Learning
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, applications, mixed_precision
from tensorflow.keras.callbacks import (
    EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
)
from tensorflow.keras.optimizers import Adam

# Scikit-learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Monitoring
import wandb

# Configuration
CONFIG = {
    # Data paths
    'dataset_path': '/kaggle/input/datasets/anshulm257/rice-disease-dataset',
    'output_dir': './models',
    'logs_dir': './logs',

    # Model
    'model_name': 'mobilenetv3_rice_disease_v1',
    'base_model': 'MobileNetV3Small',
    'img_size': (224, 224),
    'num_classes': 6,

    # Training
    'batch_size': 32,
    'kaggle_batch_size': 64,
    'epochs': 30,
    'learning_rate': 1e-3,
    'fine_tune_learning_rate': 1e-4,
    'validation_split': 0.2,
    'test_split': 0.1,
    'fine_tune_epochs': 10,
    'fine_tune_trainable_layers': 30,
    'cache_dataset': False,
    'kaggle_cache_dataset': True,
    'cache_dir': None,
    'shuffle_buffer_size': 2048,
    'enable_xla': True,
    'use_mixed_precision': True,

    # Class names
    'class_names': [
        'Bacterial Leaf Blight',
        'Brown Spot',
        'Healthy Rice Leaf',
        'Leaf Blast',
        'Leaf scald',
        'Sheath Blight'
    ],

    # Class names in Indonesian
    'class_names_id': [
        'Hawar Daun Bakteri',
        'Bercak Coklat',
        'Daun Sehat',
        'Blas Daun',
        'Hawar Seludang',
        'Blas Seludang'
    ]
}

# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)


IMAGE_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp'}


class WandbCallback(keras.callbacks.Callback):
    """Custom callback to log metrics to Weights & Biases"""
    def on_epoch_end(self, epoch, logs=None):
        if logs:
            wandb.log({
                'epoch': epoch,
                'train_loss': logs.get('loss'),
                'train_accuracy': logs.get('accuracy'),
                'train_precision': logs.get('precision'),
                'train_recall': logs.get('recall'),
                'train_auc': logs.get('auc'),
                'val_loss': logs.get('val_loss'),
                'val_accuracy': logs.get('val_accuracy'),
                'val_precision': logs.get('val_precision'),
                'val_recall': logs.get('val_recall'),
                'val_auc': logs.get('val_auc'),
            })


def get_bool_env(var_name: str, default: bool) -> bool:
    """Read boolean environment variable with a safe default."""
    value = os.environ.get(var_name)
    if value is None:
        return default
    return value.strip().lower() in {'1', 'true', 'yes', 'y', 'on'}


def is_kaggle_environment():
    """Detect whether the script is running inside Kaggle."""
    return os.environ.get("KAGGLE_KERNEL_RUN_TYPE") is not None or Path("/kaggle/input").exists()


def resolve_runtime_paths():
    """Adjust default paths so the script runs cleanly on Kaggle and locally."""
    if is_kaggle_environment():
        input_root = Path("/kaggle/input")
        dataset_override = os.environ.get("KAGGLE_DATASET_PATH")

        if dataset_override:
            CONFIG['dataset_path'] = dataset_override
        elif CONFIG['dataset_path'].startswith("./") and input_root.exists():
            inferred_dataset = auto_detect_kaggle_dataset(input_root)
            if inferred_dataset is not None:
                CONFIG['dataset_path'] = str(inferred_dataset)

        CONFIG['output_dir'] = os.environ.get("KAGGLE_OUTPUT_DIR", "/kaggle/working/models")
        CONFIG['logs_dir'] = os.environ.get("KAGGLE_LOGS_DIR", "/kaggle/working/logs")


def auto_detect_kaggle_dataset(input_root: Path):
    """Try to locate a plausible class-folder dataset without expensive deep scans."""
    if not input_root.exists():
        return None

    candidates = []
    scanned = set()

    def register_candidate(candidate: Path):
        candidate_resolved = candidate.resolve()
        if candidate_resolved in scanned:
            return
        scanned.add(candidate_resolved)

        if not candidate.is_dir():
            return

        class_dirs = [child for child in candidate.iterdir() if child.is_dir()]
        if len(class_dirs) < 2:
            return

        class_dirs_with_images = 0
        for class_dir in class_dirs:
            has_image = any(
                img_path.is_file() and img_path.suffix.lower() in IMAGE_EXTENSIONS
                for img_path in class_dir.rglob("*")
            )
            if has_image:
                class_dirs_with_images += 1
            if class_dirs_with_images >= 2:
                candidates.append(candidate)
                return

    for path in input_root.iterdir():
        if not path.is_dir():
            continue

        register_candidate(path)
        for level_1 in [d for d in path.iterdir() if d.is_dir()]:
            register_candidate(level_1)
            for level_2 in [d for d in level_1.iterdir() if d.is_dir()]:
                register_candidate(level_2)

    if not candidates:
        return None

    preferred_keywords = ("rice", "padi", "disease", "leaf", "blast")
    candidates.sort(
        key=lambda p: (
            not any(keyword in str(p).lower() for keyword in preferred_keywords),
            len(p.parts),
        )
    )
    return candidates[0]


def configure_runtime():
    """Enable GPU-friendly settings for Kaggle / T4 training."""
    print("=" * 60)
    print("RUNTIME CONFIGURATION")
    print("=" * 60)

    kaggle_mode = is_kaggle_environment()
    resolve_runtime_paths()

    if kaggle_mode:
        CONFIG['batch_size'] = int(os.environ.get("KAGGLE_BATCH_SIZE", CONFIG['kaggle_batch_size']))
        CONFIG['cache_dataset'] = get_bool_env("KAGGLE_CACHE_DATASET", CONFIG['kaggle_cache_dataset'])
        CONFIG['cache_dir'] = os.environ.get("KAGGLE_CACHE_DIR", "/kaggle/working/tf_cache")
        print("Kaggle mode detected. Applied T4 defaults.")

    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        print(f"GPU detected: {len(gpus)}")
        for gpu in gpus:
            try:
                tf.config.experimental.set_memory_growth(gpu, True)
            except RuntimeError as err:
                print(f"Could not set memory growth for {gpu.name}: {err}")

        if CONFIG.get('enable_xla', True):
            tf.config.optimizer.set_jit(True)
            print("XLA JIT: enabled")

        if CONFIG.get('use_mixed_precision', True):
            mixed_precision.set_global_policy('mixed_float16')
            print(f"Mixed precision policy: {mixed_precision.global_policy()}")
    else:
        print("GPU not detected. Training will run on CPU.")

    print(f"Dataset path: {CONFIG['dataset_path']}")
    print(f"Output dir: {CONFIG['output_dir']}")
    print(f"Logs dir: {CONFIG['logs_dir']}")
    print(f"Batch size: {CONFIG['batch_size']}")
    print(f"Cache dataset: {CONFIG['cache_dataset']}")


def create_output_directories():
    """Create output directories if they don't exist"""
    Path(CONFIG['output_dir']).mkdir(parents=True, exist_ok=True)
    Path(CONFIG['logs_dir']).mkdir(parents=True, exist_ok=True)


def list_images_with_labels(dataset_path: Path) -> Tuple[List[str], List[int], List[str]]:
    """Collect image paths and integer labels from a class-per-folder dataset."""
    class_dirs = sorted([path for path in dataset_path.iterdir() if path.is_dir()])
    if not class_dirs:
        raise ValueError(f"No class folders found under {dataset_path}")

    class_names = [path.name for path in class_dirs]
    image_paths = []
    labels = []

    for class_idx, class_dir in enumerate(class_dirs):
        class_images = sorted(
            [
                str(path)
                for path in class_dir.rglob("*")
                if path.is_file() and path.suffix.lower() in IMAGE_EXTENSIONS
            ]
        )
        image_paths.extend(class_images)
        labels.extend([class_idx] * len(class_images))

    if not image_paths:
        raise ValueError(f"No images found under {dataset_path}")

    return image_paths, labels, class_names


def decode_and_resize_image(file_path, label):
    """Load an image file and convert label to one-hot."""
    image = tf.io.read_file(file_path)
    image = tf.image.decode_image(image, channels=3, expand_animations=False)
    image.set_shape([None, None, 3])
    image = tf.image.resize(image, CONFIG['img_size'])
    image = tf.cast(image, tf.float32)
    label = tf.one_hot(label, depth=CONFIG['num_classes'])
    return image, label


def build_tf_dataset(file_paths, labels, training=False, split_name='dataset'):
    """Build a tf.data pipeline from file paths."""
    dataset = tf.data.Dataset.from_tensor_slices((file_paths, labels))

    if training:
        shuffle_buffer = min(len(file_paths), int(CONFIG.get('shuffle_buffer_size', 2048)))
        dataset = dataset.shuffle(buffer_size=shuffle_buffer, seed=42, reshuffle_each_iteration=True)

    options = tf.data.Options()
    options.experimental_deterministic = not training
    dataset = dataset.with_options(options)

    dataset = dataset.map(
        decode_and_resize_image,
        num_parallel_calls=tf.data.AUTOTUNE,
        deterministic=not training
    )

    if CONFIG.get('cache_dataset', False):
        cache_dir = CONFIG.get('cache_dir')
        if cache_dir:
            cache_path = Path(cache_dir) / f"{split_name}.cache"
            cache_path.parent.mkdir(parents=True, exist_ok=True)
            dataset = dataset.cache(str(cache_path))
        else:
            dataset = dataset.cache()

    dataset = dataset.batch(CONFIG['batch_size'])
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset


def load_data():
    """Load and prepare image dataset."""
    print("=" * 60)
    print("LOADING DATASET")
    print("=" * 60)

    dataset_path = Path(CONFIG['dataset_path'])

    if not dataset_path.exists():
        raise FileNotFoundError(
            f"Dataset not found at {dataset_path}. "
            "For Kaggle, attach the dataset and optionally set KAGGLE_DATASET_PATH."
        )

    has_split = all((dataset_path / s).exists() for s in ['train', 'val', 'test'])

    # Drill down logic: If the path contains only one directory and no images, 
    # the real dataset is likely one level deeper (common in Kaggle/Zips)
    if not has_split:
        class_dirs = [d for d in dataset_path.iterdir() if d.is_dir()]
        if len(class_dirs) == 1:
            sub_dirs = [d for d in class_dirs[0].iterdir() if d.is_dir()]
            if len(sub_dirs) >= 2:
                print(f"ℹ️ Single parent directory '{class_dirs[0].name}' detected. Drilling down to sub-folders...")
                dataset_path = class_dirs[0]

    if has_split:
        print("Dataset already has train/val/test split")

        train_files, train_labels, class_names = list_images_with_labels(dataset_path / 'train')
        val_files, val_labels, _ = list_images_with_labels(dataset_path / 'val')
        test_files, test_labels, _ = list_images_with_labels(dataset_path / 'test')
    else:
        print("Dataset not split. Creating stratified train/val/test split...")

        all_files, all_labels, class_names = list_images_with_labels(dataset_path)

        train_files, holdout_files, train_labels, holdout_labels = train_test_split(
            all_files,
            all_labels,
            test_size=CONFIG['validation_split'] + CONFIG['test_split'],
            random_state=42,
            stratify=all_labels
        )

        relative_test_size = CONFIG['test_split'] / (CONFIG['validation_split'] + CONFIG['test_split'])
        val_files, test_files, val_labels, test_labels = train_test_split(
            holdout_files,
            holdout_labels,
            test_size=relative_test_size,
            random_state=42,
            stratify=holdout_labels
        )

    CONFIG['class_names'] = class_names
    CONFIG['num_classes'] = len(class_names)
    print(f"Classes found: {CONFIG['class_names']}")

    train_ds = build_tf_dataset(train_files, train_labels, training=True, split_name='train')
    val_ds = build_tf_dataset(val_files, val_labels, training=False, split_name='val')
    test_ds = build_tf_dataset(test_files, test_labels, training=False, split_name='test')

    print(f"\nTrain samples: {len(train_files)}")
    print(f"Val samples: {len(val_files)}")
    print(f"Test samples: {len(test_files)}")

    return train_ds, val_ds, test_ds


def build_model(num_classes):
    """
    Build model using transfer learning with MobileNetV3
    """
    print("=" * 60)
    print("BUILDING MODEL")
    print("=" * 60)

    # Data augmentation
    data_augmentation = models.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ], name="data_augmentation")

    # Load pre-trained model
    base_model = applications.MobileNetV3Small(
        input_shape=(*CONFIG['img_size'], 3),
        include_top=False,
        weights='imagenet',
        include_preprocessing=True
    )

    # Freeze base model
    base_model.trainable = False

    # Build model
    inputs = layers.Input(shape=(*CONFIG['img_size'], 3))
    x = data_augmentation(inputs)
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = models.Model(inputs, outputs, name=CONFIG['model_name'])

    print(f"\nModel: {CONFIG['model_name']}")
    print(f"Base: {CONFIG['base_model']}")
    print(f"Input shape: {(*CONFIG['img_size'], 3)}")
    print(f"Output classes: {num_classes}")

    model.summary()

    return model, base_model


def compile_model(model, learning_rate=None):
    """Compile model with optimizer and metrics"""
    optimizer = Adam(learning_rate=learning_rate or CONFIG['learning_rate'])

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=[
            'accuracy',
            keras.metrics.Precision(name='precision'),
            keras.metrics.Recall(name='recall'),
            keras.metrics.AUC(name='auc')
        ]
    )

    return model


def create_callbacks():
    """Create training callbacks"""
    checkpoint_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_best.keras"
    csv_path = Path(CONFIG['logs_dir']) / f"{CONFIG['model_name']}_training_log.csv"

    callbacks = [
        # Save best model
        ModelCheckpoint(
            str(checkpoint_path),
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        ),

        # Early stopping
        EarlyStopping(
            monitor='val_accuracy',
            patience=8,
            mode='max',
            verbose=1,
            restore_best_weights=True
        ),

        # Reduce learning rate
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=4,
            min_lr=1e-7,
            verbose=1
        ),

        # CSV logger
        CSVLogger(str(csv_path)),
        
        # Custom W&B Callback
        WandbCallback()
    ]

    return callbacks


def train_model(model, train_ds, val_ds):
    """
    Train the model
    """
    print("=" * 60)
    print("TRAINING MODEL")
    print("=" * 60)

    callbacks = create_callbacks()
    
    # Log training config to W&B
    wandb.config.update({
        'learning_rate': CONFIG['learning_rate'],
        'batch_size': CONFIG['batch_size'],
        'epochs': CONFIG['epochs'],
        'model_name': CONFIG['model_name'],
        'base_model': CONFIG['base_model']
    })

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=CONFIG['epochs'],
        callbacks=callbacks,
        verbose=1
    )

    return history


def fine_tune_model(model, base_model, train_ds, val_ds):
    """
    Fine-tune the model by unfreezing some layers
    """
    print("=" * 60)
    print("FINE-TUNING MODEL")
    print("=" * 60)

    # Unfreeze the base model
    base_model.trainable = True

    # Freeze all layers except the last N
    for layer in base_model.layers[:-CONFIG['fine_tune_trainable_layers']]:
        layer.trainable = False

    # Recompile with lower learning rate
    model = compile_model(model, learning_rate=CONFIG['fine_tune_learning_rate'])

    # Fine-tune
    initial_epoch = CONFIG['epochs']
    total_epochs = CONFIG['epochs'] + CONFIG['fine_tune_epochs']
    history_fine = model.fit(
        train_ds,
        validation_data=val_ds,
        initial_epoch=initial_epoch,
        epochs=total_epochs,
        callbacks=create_callbacks(),
        verbose=1
    )

    return history_fine


def evaluate_model(model, test_ds):
    """
    Evaluate model on test set
    """
    print("=" * 60)
    print("EVALUATING MODEL")
    print("=" * 60)

    # Get predictions
    y_pred_probs = model.predict(test_ds)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Get true labels
    y_true = np.concatenate([y for x, y in test_ds], axis=0)
    y_true = np.argmax(y_true, axis=1)

    # Print classification report
    print("\nClassification Report:")
    print(classification_report(
        y_true,
        y_pred,
        target_names=CONFIG['class_names'],
        digits=4
    ))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        xticklabels=CONFIG['class_names'],
        yticklabels=CONFIG['class_names']
    )
    plt.title('Confusion Matrix - Rice Disease Detection')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    cm_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_confusion_matrix.png"
    plt.savefig(cm_path, dpi=150)
    print(f"\nConfusion matrix saved to: {cm_path}")
    
    # Log confusion matrix to W&B
    wandb.log({'confusion_matrix': wandb.Image(str(cm_path))})

    # Calculate metrics
    test_loss, test_acc, test_precision, test_recall, test_auc = model.evaluate(test_ds, verbose=0)

    print("\n" + "=" * 60)
    print("TEST METRICS")
    print("=" * 60)
    print(f"Test Accuracy:  {test_acc:.4f}")
    print(f"Test Precision: {test_precision:.4f}")
    print(f"Test Recall:    {test_recall:.4f}")
    print(f"Test AUC:       {test_auc:.4f}")
    f1_score = (
        2 * (test_precision * test_recall) / (test_precision + test_recall)
        if (test_precision + test_recall) > 0 else 0.0
    )
    print(f"Test F1-Score:  {f1_score:.4f}")
    print("=" * 60)
    
    # Log test metrics to W&B
    wandb.log({
        'test_loss': test_loss,
        'test_accuracy': test_acc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_auc': test_auc,
        'test_f1_score': f1_score
    })

    return {
        'accuracy': float(test_acc),
        'precision': float(test_precision),
        'recall': float(test_recall),
        'auc': float(test_auc),
        'f1_score': float(f1_score)
    }


def save_model_and_artifacts(model, metrics):
    """
    Save model, config, and metrics
    """
    print("\n" + "=" * 60)
    print("SAVING MODEL AND ARTIFACTS")
    print("=" * 60)

    # Save final model
    final_model_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_final.keras"
    model.save(final_model_path)
    print(f"Model saved to: {final_model_path}")
    
    # Log model to W&B
    wandb.save(str(final_model_path))

    # Save as TensorFlow SavedModel format
    saved_model_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_savedmodel"
    try:
        model.export(saved_model_path)
    except AttributeError:
        tf.saved_model.save(model, saved_model_path)
    print(f"SavedModel exported to: {saved_model_path}")
    
    # Log SavedModel to W&B
    wandb.save(str(saved_model_path))

    # Save config
    config_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_config.json"
    with open(config_path, 'w') as f:
        json.dump(CONFIG, f, indent=2)
    print(f"Config saved to: {config_path}")
    
    # Log config to W&B
    wandb.save(str(config_path))

    # Save metrics
    metrics_with_timestamp = {
        'timestamp': datetime.now().isoformat(),
        'model_name': CONFIG['model_name'],
        'metrics': metrics,
        'config': CONFIG
    }

    metrics_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_metrics.json"
    with open(metrics_path, 'w') as f:
        json.dump(metrics_with_timestamp, f, indent=2)
    print(f"Metrics saved to: {metrics_path}")
    
    # Log final metrics to W&B
    wandb.log({
        'final_metrics': metrics,
        'timestamp': datetime.now().isoformat()
    })

    print("\n" + "=" * 60)
    print("TRAINING COMPLETE!")
    print("=" * 60)


def plot_training_history(history, history_fine=None):
    """
    Plot and save training history
    """
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Accuracy
    axes[0].plot(history.history['accuracy'], label='Train Accuracy')
    axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
    if history_fine:
        axes[0].plot(
            range(len(history.history['accuracy']), len(history.history['accuracy']) + len(history_fine.history['accuracy'])),
            history_fine.history['accuracy'],
            label='Fine-tune Train Accuracy',
            linestyle='--'
        )
        axes[0].plot(
            range(len(history.history['accuracy']), len(history.history['accuracy']) + len(history_fine.history['accuracy'])),
            history_fine.history['val_accuracy'],
            label='Fine-tune Val Accuracy',
            linestyle='--'
        )
    axes[0].set_title('Model Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    # Loss
    axes[1].plot(history.history['loss'], label='Train Loss')
    axes[1].plot(history.history['val_loss'], label='Val Loss')
    if history_fine:
        axes[1].plot(
            range(len(history.history['loss']), len(history.history['loss']) + len(history_fine.history['loss'])),
            history_fine.history['loss'],
            label='Fine-tune Train Loss',
            linestyle='--'
        )
        axes[1].plot(
            range(len(history.history['loss']), len(history.history['loss']) + len(history_fine.history['loss'])),
            history_fine.history['val_loss'],
            label='Fine-tune Val Loss',
            linestyle='--'
        )
    axes[1].set_title('Model Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()

    history_path = Path(CONFIG['output_dir']) / f"{CONFIG['model_name']}_training_history.png"
    plt.savefig(history_path, dpi=150)
    print(f"Training history plot saved to: {history_path}")
    
    # Log training history plot to W&B
    wandb.log({'training_history': wandb.Image(str(history_path))})


def main():
    """Main training pipeline"""
    print("\n" + "=" * 60)
    print("KARAWANG PADI GUARD - DISEASE DETECTION TRAINING")
    print("=" * 60)
    print(f"Start Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print("=" * 60 + "\n")

    # Initialize Weights & Biases
    wandb.init(
        project='karawang-padi-guard',
        name=CONFIG['model_name'],
        config=CONFIG,
        tags=['computer-vision', 'disease-detection', 'mobilenetv3', 'transfer-learning'],
        notes='Rice disease detection using MobileNetV3 with transfer learning and fine-tuning'
    )
    
    print(f"W&B Project: {wandb.run.project}")
    print(f"W&B Run Name: {wandb.run.name}")
    print(f"W&B Run ID: {wandb.run.id}\n")

    try:
        configure_runtime()

        # Create directories
        create_output_directories()

        # Load data
        train_ds, val_ds, test_ds = load_data()

        # Build model
        model, base_model = build_model(num_classes=CONFIG['num_classes'])

        # Compile model
        model = compile_model(model)

        # Train model
        history = train_model(model, train_ds, val_ds)

        # Fine-tune model
        history_fine = fine_tune_model(model, base_model, train_ds, val_ds)

        # Plot training history
        plot_training_history(history, history_fine)

        # Evaluate model
        metrics = evaluate_model(model, test_ds)

        # Save model and artifacts
        save_model_and_artifacts(model, metrics)

        print(f"\nEnd Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print("\nTraining completed successfully!")
        
        # Finish W&B run
        wandb.finish()
        
    except Exception as e:
        print(f"\nError during training: {str(e)}")
        wandb.finish(exit_code=1)
        raise


if __name__ == "__main__":
    main()
# Out:
# ============================================================
# KARAWANG PADI GUARD - DISEASE DETECTION TRAINING
# ============================================================
# Start Time: 2026-04-28 16:41:14
# ============================================================
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#   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
# wandb: WARNING Invalid choice
# wandb: Enter your choice:
#   1
# wandb: You chose 'Create a W&B account'
# wandb: Create an account here: https://wandb.ai/authorize?signup=true&ref=models
# wandb: After creating your account, create a new API key and store it securely.
# wandb: Paste your API key and hit enter:
#   ········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: yesayasentosa (yesayasentosa-politeknik-negeri-batam) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260428_164322-lopkd1re</code>
# Syncing run <strong><a href='https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard/runs/lopkd1re' target="_blank">mobilenetv3_rice_disease_v1</a></strong> to <a href='https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard' target="_blank">https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard</a>
#  View run at <a href='https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard/runs/lopkd1re' target="_blank">https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard/runs/lopkd1re</a>
# W&B Project: karawang-padi-guard
# W&B Run Name: mobilenetv3_rice_disease_v1
# W&B Run ID: lopkd1re
#
# ============================================================
# RUNTIME CONFIGURATION
# ============================================================
# Kaggle mode detected. Applied T4 defaults.
# GPU detected: 2
# XLA JIT: enabled
# Mixed precision policy: <DTypePolicy "mixed_float16">
# Dataset path: /kaggle/input/datasets/anshulm257/rice-disease-dataset
# Output dir: /kaggle/working/models
# Logs dir: /kaggle/working/logs
# Batch size: 64
# Cache dataset: True
# ============================================================
# LOADING DATASET
# ============================================================
# ℹ️ Single parent directory 'Rice_Leaf_AUG' detected. Drilling down to sub-folders...
# Dataset not split. Creating stratified train/val/test split...
# Classes found: ['Bacterial Leaf Blight', 'Brown Spot', 'Healthy Rice Leaf', 'Leaf Blast', 'Leaf scald', 'Sheath Blight']
# I0000 00:00:1777394631.406923      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777394631.413322      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Train samples: 2680
# Val samples: 766
# Test samples: 383
# ============================================================
# BUILDING MODEL
# ============================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Model: mobilenetv3_rice_disease_v1
# Base: MobileNetV3Small
# Input shape: (224, 224, 3)
# Output classes: 6
# Model: "mobilenetv3_rice_disease_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV3Small (Functional)   │ (None, 7, 7, 576)      │       939,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 576)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       147,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,088,374 (4.15 MB)
#  Trainable params: 149,254 (583.02 KB)
#  Non-trainable params: 939,120 (3.58 MB)
# ============================================================
# TRAINING MODEL
# ============================================================
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777394643.616829     193 service.cc:152] XLA service 0x4749daf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777394643.616881     193 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1777394643.616886     193 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1777394643.807515     193 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1777394644.926650     193 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.3376 - auc: 0.6953 - loss: 1.6362 - precision: 0.4806 - recall: 0.1319
# Epoch 1: val_accuracy improved from -inf to 0.66449, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.3401 - auc: 0.6976 - loss: 1.6305 - precision: 0.4847 - recall: 0.1345 - val_accuracy: 0.6645 - val_auc: 0.9204 - val_loss: 0.9315 - val_precision: 0.8136 - val_recall: 0.4386 - learning_rate: 0.0010
# Epoch 2/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - accuracy: 0.6100 - auc: 0.8919 - loss: 1.0326 - precision: 0.7356 - recall: 0.4731
# Epoch 2: val_accuracy improved from 0.66449 to 0.71932, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.6103 - auc: 0.8921 - loss: 1.0318 - precision: 0.7359 - recall: 0.4734 - val_accuracy: 0.7193 - val_auc: 0.9403 - val_loss: 0.7992 - val_precision: 0.8163 - val_recall: 0.5744 - learning_rate: 0.0010
# Epoch 3/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6497 - auc: 0.9121 - loss: 0.9340 - precision: 0.7575 - recall: 0.5228
# Epoch 3: val_accuracy improved from 0.71932 to 0.74543, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6506 - auc: 0.9125 - loss: 0.9319 - precision: 0.7579 - recall: 0.5237 - val_accuracy: 0.7454 - val_auc: 0.9535 - val_loss: 0.7079 - val_precision: 0.8385 - val_recall: 0.6305 - learning_rate: 0.0010
# Epoch 4/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6856 - auc: 0.9291 - loss: 0.8393 - precision: 0.7817 - recall: 0.5796
# Epoch 4: val_accuracy improved from 0.74543 to 0.75718, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6860 - auc: 0.9293 - loss: 0.8385 - precision: 0.7814 - recall: 0.5798 - val_accuracy: 0.7572 - val_auc: 0.9558 - val_loss: 0.6754 - val_precision: 0.8306 - val_recall: 0.6593 - learning_rate: 0.0010
# Epoch 5/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7098 - auc: 0.9381 - loss: 0.7849 - precision: 0.8043 - recall: 0.6165
# Epoch 5: val_accuracy improved from 0.75718 to 0.76240, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.7101 - auc: 0.9382 - loss: 0.7840 - precision: 0.8041 - recall: 0.6169 - val_accuracy: 0.7624 - val_auc: 0.9577 - val_loss: 0.6510 - val_precision: 0.8211 - val_recall: 0.6710 - learning_rate: 0.0010
# Epoch 6/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7068 - auc: 0.9408 - loss: 0.7671 - precision: 0.7859 - recall: 0.6250
# Epoch 6: val_accuracy improved from 0.76240 to 0.79243, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7071 - auc: 0.9408 - loss: 0.7672 - precision: 0.7860 - recall: 0.6252 - val_accuracy: 0.7924 - val_auc: 0.9633 - val_loss: 0.6195 - val_precision: 0.8382 - val_recall: 0.6762 - learning_rate: 0.0010
# Epoch 7/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7178 - auc: 0.9435 - loss: 0.7495 - precision: 0.7964 - recall: 0.6279
# Epoch 7: val_accuracy improved from 0.79243 to 0.79504, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7181 - auc: 0.9436 - loss: 0.7487 - precision: 0.7965 - recall: 0.6286 - val_accuracy: 0.7950 - val_auc: 0.9656 - val_loss: 0.5963 - val_precision: 0.8454 - val_recall: 0.7141 - learning_rate: 0.0010
# Epoch 8/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7477 - auc: 0.9498 - loss: 0.7048 - precision: 0.8184 - recall: 0.6603
# Epoch 8: val_accuracy improved from 0.79504 to 0.80157, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7479 - auc: 0.9498 - loss: 0.7044 - precision: 0.8184 - recall: 0.6605 - val_accuracy: 0.8016 - val_auc: 0.9652 - val_loss: 0.5914 - val_precision: 0.8407 - val_recall: 0.7167 - learning_rate: 0.0010
# Epoch 9/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7441 - auc: 0.9514 - loss: 0.6916 - precision: 0.8231 - recall: 0.6634
# Epoch 9: val_accuracy improved from 0.80157 to 0.81201, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7441 - auc: 0.9515 - loss: 0.6913 - precision: 0.8231 - recall: 0.6636 - val_accuracy: 0.8120 - val_auc: 0.9692 - val_loss: 0.5584 - val_precision: 0.8472 - val_recall: 0.7454 - learning_rate: 0.0010
# Epoch 10/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7530 - auc: 0.9559 - loss: 0.6634 - precision: 0.8190 - recall: 0.6691
# Epoch 10: val_accuracy improved from 0.81201 to 0.81593, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7531 - auc: 0.9560 - loss: 0.6630 - precision: 0.8190 - recall: 0.6693 - val_accuracy: 0.8159 - val_auc: 0.9705 - val_loss: 0.5478 - val_precision: 0.8552 - val_recall: 0.7480 - learning_rate: 0.0010
# Epoch 11/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7642 - auc: 0.9587 - loss: 0.6393 - precision: 0.8317 - recall: 0.6996
# Epoch 11: val_accuracy did not improve from 0.81593
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.7643 - auc: 0.9587 - loss: 0.6390 - precision: 0.8315 - recall: 0.6994 - val_accuracy: 0.8120 - val_auc: 0.9703 - val_loss: 0.5448 - val_precision: 0.8420 - val_recall: 0.7585 - learning_rate: 0.0010
# Epoch 12/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7615 - auc: 0.9594 - loss: 0.6320 - precision: 0.8273 - recall: 0.6986
# Epoch 12: val_accuracy improved from 0.81593 to 0.82245, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7619 - auc: 0.9595 - loss: 0.6314 - precision: 0.8276 - recall: 0.6986 - val_accuracy: 0.8225 - val_auc: 0.9722 - val_loss: 0.5263 - val_precision: 0.8559 - val_recall: 0.7676 - learning_rate: 0.0010
# Epoch 13/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7826 - auc: 0.9641 - loss: 0.5965 - precision: 0.8377 - recall: 0.7152
# Epoch 13: val_accuracy did not improve from 0.82245
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.7825 - auc: 0.9641 - loss: 0.5967 - precision: 0.8375 - recall: 0.7151 - val_accuracy: 0.8159 - val_auc: 0.9724 - val_loss: 0.5239 - val_precision: 0.8605 - val_recall: 0.7650 - learning_rate: 0.0010
# Epoch 14/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7608 - auc: 0.9581 - loss: 0.6431 - precision: 0.8262 - recall: 0.6816
# Epoch 14: val_accuracy did not improve from 0.82245
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.7611 - auc: 0.9581 - loss: 0.6424 - precision: 0.8264 - recall: 0.6819 - val_accuracy: 0.8172 - val_auc: 0.9749 - val_loss: 0.5061 - val_precision: 0.8642 - val_recall: 0.7728 - learning_rate: 0.0010
# Epoch 15/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7924 - auc: 0.9668 - loss: 0.5744 - precision: 0.8483 - recall: 0.7181
# Epoch 15: val_accuracy improved from 0.82245 to 0.82376, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7923 - auc: 0.9669 - loss: 0.5737 - precision: 0.8484 - recall: 0.7187 - val_accuracy: 0.8238 - val_auc: 0.9759 - val_loss: 0.4912 - val_precision: 0.8650 - val_recall: 0.7781 - learning_rate: 0.0010
# Epoch 16/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7978 - auc: 0.9678 - loss: 0.5622 - precision: 0.8505 - recall: 0.7276
# Epoch 16: val_accuracy improved from 0.82376 to 0.82898, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7979 - auc: 0.9679 - loss: 0.5615 - precision: 0.8505 - recall: 0.7280 - val_accuracy: 0.8290 - val_auc: 0.9764 - val_loss: 0.4793 - val_precision: 0.8633 - val_recall: 0.7833 - learning_rate: 0.0010
# Epoch 17/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8171 - auc: 0.9747 - loss: 0.5036 - precision: 0.8693 - recall: 0.7572
# Epoch 17: val_accuracy improved from 0.82898 to 0.83029, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8167 - auc: 0.9747 - loss: 0.5043 - precision: 0.8688 - recall: 0.7569 - val_accuracy: 0.8303 - val_auc: 0.9755 - val_loss: 0.4875 - val_precision: 0.8790 - val_recall: 0.7963 - learning_rate: 0.0010
# Epoch 18/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7885 - auc: 0.9677 - loss: 0.5612 - precision: 0.8353 - recall: 0.7256
# Epoch 18: val_accuracy improved from 0.83029 to 0.84726, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.7888 - auc: 0.9678 - loss: 0.5605 - precision: 0.8356 - recall: 0.7261 - val_accuracy: 0.8473 - val_auc: 0.9783 - val_loss: 0.4589 - val_precision: 0.8755 - val_recall: 0.7898 - learning_rate: 0.0010
# Epoch 19/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7977 - auc: 0.9704 - loss: 0.5418 - precision: 0.8540 - recall: 0.7440
# Epoch 19: val_accuracy improved from 0.84726 to 0.85770, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7983 - auc: 0.9705 - loss: 0.5405 - precision: 0.8544 - recall: 0.7445 - val_accuracy: 0.8577 - val_auc: 0.9799 - val_loss: 0.4431 - val_precision: 0.8826 - val_recall: 0.8146 - learning_rate: 0.0010
# Epoch 20/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8221 - auc: 0.9729 - loss: 0.5134 - precision: 0.8718 - recall: 0.7706
# Epoch 20: val_accuracy improved from 0.85770 to 0.86031, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8222 - auc: 0.9729 - loss: 0.5133 - precision: 0.8717 - recall: 0.7707 - val_accuracy: 0.8603 - val_auc: 0.9805 - val_loss: 0.4331 - val_precision: 0.8894 - val_recall: 0.8185 - learning_rate: 0.0010
# Epoch 21/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8243 - auc: 0.9771 - loss: 0.4781 - precision: 0.8663 - recall: 0.7781
# Epoch 21: val_accuracy did not improve from 0.86031
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8241 - auc: 0.9770 - loss: 0.4785 - precision: 0.8662 - recall: 0.7780 - val_accuracy: 0.8407 - val_auc: 0.9789 - val_loss: 0.4510 - val_precision: 0.8672 - val_recall: 0.8016 - learning_rate: 0.0010
# Epoch 22/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8049 - auc: 0.9747 - loss: 0.5000 - precision: 0.8516 - recall: 0.7569
# Epoch 22: val_accuracy did not improve from 0.86031
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8052 - auc: 0.9748 - loss: 0.4996 - precision: 0.8518 - recall: 0.7572 - val_accuracy: 0.8499 - val_auc: 0.9800 - val_loss: 0.4383 - val_precision: 0.8748 - val_recall: 0.8029 - learning_rate: 0.0010
# Epoch 23/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8209 - auc: 0.9773 - loss: 0.4755 - precision: 0.8612 - recall: 0.7726
# Epoch 23: val_accuracy improved from 0.86031 to 0.86815, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8209 - auc: 0.9773 - loss: 0.4755 - precision: 0.8612 - recall: 0.7726 - val_accuracy: 0.8681 - val_auc: 0.9818 - val_loss: 0.4169 - val_precision: 0.8979 - val_recall: 0.8381 - learning_rate: 0.0010
# Epoch 24/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8262 - auc: 0.9797 - loss: 0.4491 - precision: 0.8735 - recall: 0.7793
# Epoch 24: val_accuracy improved from 0.86815 to 0.87076, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8262 - auc: 0.9797 - loss: 0.4491 - precision: 0.8733 - recall: 0.7792 - val_accuracy: 0.8708 - val_auc: 0.9831 - val_loss: 0.3988 - val_precision: 0.9004 - val_recall: 0.8381 - learning_rate: 0.0010
# Epoch 25/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8436 - auc: 0.9810 - loss: 0.4337 - precision: 0.8793 - recall: 0.8087
# Epoch 25: val_accuracy did not improve from 0.87076
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8434 - auc: 0.9809 - loss: 0.4339 - precision: 0.8791 - recall: 0.8084 - val_accuracy: 0.8655 - val_auc: 0.9821 - val_loss: 0.4066 - val_precision: 0.8966 - val_recall: 0.8381 - learning_rate: 0.0010
# Epoch 26/30
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8401 - auc: 0.9795 - loss: 0.4477 - precision: 0.8822 - recall: 0.8078
# Epoch 26: val_accuracy did not improve from 0.87076
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8402 - auc: 0.9795 - loss: 0.4477 - precision: 0.8822 - recall: 0.8078 - val_accuracy: 0.8708 - val_auc: 0.9817 - val_loss: 0.4151 - val_precision: 0.9006 - val_recall: 0.8394 - learning_rate: 0.0010
# Epoch 27/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8223 - auc: 0.9792 - loss: 0.4521 - precision: 0.8665 - recall: 0.7851
# Epoch 27: val_accuracy did not improve from 0.87076
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8225 - auc: 0.9792 - loss: 0.4524 - precision: 0.8667 - recall: 0.7854 - val_accuracy: 0.8668 - val_auc: 0.9829 - val_loss: 0.4063 - val_precision: 0.8933 - val_recall: 0.8303 - learning_rate: 0.0010
# Epoch 28/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8471 - auc: 0.9822 - loss: 0.4208 - precision: 0.8848 - recall: 0.8036
# Epoch 28: val_accuracy did not improve from 0.87076
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8470 - auc: 0.9821 - loss: 0.4211 - precision: 0.8847 - recall: 0.8036 - val_accuracy: 0.8668 - val_auc: 0.9830 - val_loss: 0.4005 - val_precision: 0.8906 - val_recall: 0.8394 - learning_rate: 0.0010
# Epoch 29/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8401 - auc: 0.9822 - loss: 0.4157 - precision: 0.8773 - recall: 0.7994
# Epoch 29: val_accuracy improved from 0.87076 to 0.87728, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8407 - auc: 0.9823 - loss: 0.4148 - precision: 0.8780 - recall: 0.8003 - val_accuracy: 0.8773 - val_auc: 0.9844 - val_loss: 0.3846 - val_precision: 0.9010 - val_recall: 0.8433 - learning_rate: 5.0000e-04
# Epoch 30/30
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8640 - auc: 0.9836 - loss: 0.3940 - precision: 0.8952 - recall: 0.8306
# Epoch 30: val_accuracy improved from 0.87728 to 0.88903, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8636 - auc: 0.9836 - loss: 0.3947 - precision: 0.8948 - recall: 0.8299 - val_accuracy: 0.8890 - val_auc: 0.9850 - val_loss: 0.3744 - val_precision: 0.9079 - val_recall: 0.8499 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 30.
# ============================================================
# FINE-TUNING MODEL
# ============================================================
# Epoch 31/40
# 2026-04-28 16:48:10.443027: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-28 16:48:10.603377: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-28 16:48:10.737008: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5764 - auc: 0.8522 - loss: 1.6865 - precision: 0.6004 - recall: 0.5442
# Epoch 31: val_accuracy improved from -inf to 0.73890, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 62s 568ms/step - accuracy: 0.5779 - auc: 0.8531 - loss: 1.6764 - precision: 0.6020 - recall: 0.5455 - val_accuracy: 0.7389 - val_auc: 0.9448 - val_loss: 0.7732 - val_precision: 0.7773 - val_recall: 0.7063 - learning_rate: 1.0000e-04
# Epoch 32/40
# 40/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7696 - auc: 0.9577 - loss: 0.6416 - precision: 0.8157 - recall: 0.7305
# 2026-04-28 16:49:02.309956: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-28 16:49:02.444526: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.7699 - auc: 0.9578 - loss: 0.6404 - precision: 0.8159 - recall: 0.7309
# Epoch 32: val_accuracy did not improve from 0.73890
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 39s 952ms/step - accuracy: 0.7700 - auc: 0.9579 - loss: 0.6398 - precision: 0.8160 - recall: 0.7311 - val_accuracy: 0.7376 - val_auc: 0.9439 - val_loss: 0.7883 - val_precision: 0.7683 - val_recall: 0.6971 - learning_rate: 1.0000e-04
# Epoch 33/40
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7839 - auc: 0.9652 - loss: 0.5850 - precision: 0.8280 - recall: 0.7497
# Epoch 33: val_accuracy improved from 0.73890 to 0.74674, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.7843 - auc: 0.9654 - loss: 0.5838 - precision: 0.8282 - recall: 0.7501 - val_accuracy: 0.7467 - val_auc: 0.9452 - val_loss: 0.7839 - val_precision: 0.7751 - val_recall: 0.7063 - learning_rate: 1.0000e-04
# Epoch 34/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8225 - auc: 0.9774 - loss: 0.4674 - precision: 0.8606 - recall: 0.7808
# Epoch 34: val_accuracy improved from 0.74674 to 0.75979, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8226 - auc: 0.9774 - loss: 0.4674 - precision: 0.8606 - recall: 0.7811 - val_accuracy: 0.7598 - val_auc: 0.9514 - val_loss: 0.7203 - val_precision: 0.7820 - val_recall: 0.7258 - learning_rate: 1.0000e-04
# Epoch 35/40
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8484 - auc: 0.9789 - loss: 0.4432 - precision: 0.8822 - recall: 0.8122
# Epoch 35: val_accuracy improved from 0.75979 to 0.77024, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8485 - auc: 0.9789 - loss: 0.4424 - precision: 0.8822 - recall: 0.8123 - val_accuracy: 0.7702 - val_auc: 0.9544 - val_loss: 0.7001 - val_precision: 0.7932 - val_recall: 0.7363 - learning_rate: 1.0000e-04
# Epoch 36/40
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8503 - auc: 0.9836 - loss: 0.3963 - precision: 0.8792 - recall: 0.8239
# Epoch 36: val_accuracy improved from 0.77024 to 0.79243, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8506 - auc: 0.9836 - loss: 0.3959 - precision: 0.8794 - recall: 0.8241 - val_accuracy: 0.7924 - val_auc: 0.9609 - val_loss: 0.6301 - val_precision: 0.8150 - val_recall: 0.7650 - learning_rate: 1.0000e-04
# Epoch 37/40
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8779 - auc: 0.9859 - loss: 0.3665 - precision: 0.9019 - recall: 0.8424
# Epoch 37: val_accuracy improved from 0.79243 to 0.79634, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8778 - auc: 0.9859 - loss: 0.3663 - precision: 0.9019 - recall: 0.8426 - val_accuracy: 0.7963 - val_auc: 0.9625 - val_loss: 0.6127 - val_precision: 0.8155 - val_recall: 0.7676 - learning_rate: 1.0000e-04
# Epoch 38/40
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8835 - auc: 0.9885 - loss: 0.3325 - precision: 0.9105 - recall: 0.8485
# Epoch 38: val_accuracy improved from 0.79634 to 0.79765, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8833 - auc: 0.9885 - loss: 0.3327 - precision: 0.9103 - recall: 0.8485 - val_accuracy: 0.7977 - val_auc: 0.9639 - val_loss: 0.5980 - val_precision: 0.8198 - val_recall: 0.7663 - learning_rate: 1.0000e-04
# Epoch 39/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8795 - auc: 0.9896 - loss: 0.3180 - precision: 0.9096 - recall: 0.8565
# Epoch 39: val_accuracy did not improve from 0.79765
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8797 - auc: 0.9896 - loss: 0.3178 - precision: 0.9096 - recall: 0.8567 - val_accuracy: 0.7963 - val_auc: 0.9673 - val_loss: 0.5714 - val_precision: 0.8255 - val_recall: 0.7781 - learning_rate: 1.0000e-04
# Epoch 40/40
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8846 - auc: 0.9880 - loss: 0.3321 - precision: 0.9070 - recall: 0.8606
# Epoch 40: val_accuracy improved from 0.79765 to 0.80287, saving model to /kaggle/working/models/mobilenetv3_rice_disease_v1_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8846 - auc: 0.9881 - loss: 0.3319 - precision: 0.9070 - recall: 0.8607 - val_accuracy: 0.8029 - val_auc: 0.9684 - val_loss: 0.5590 - val_precision: 0.8322 - val_recall: 0.7833 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 40.
# Training history plot saved to: /kaggle/working/models/mobilenetv3_rice_disease_v1_training_history.png
# ============================================================
# EVALUATING MODEL
# ============================================================
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 43s 6s/step
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# Bacterial Leaf Blight     0.7333    0.8594    0.7914        64
#            Brown Spot     0.8657    0.8923    0.8788        65
#     Healthy Rice Leaf     0.9844    0.9692    0.9767        65
#            Leaf Blast     0.7027    0.8254    0.7591        63
#            Leaf scald     0.8254    0.8254    0.8254        63
#         Sheath Blight     1.0000    0.6349    0.7767        63
#
#              accuracy                         0.8355       383
#             macro avg     0.8519    0.8344    0.8347       383
#          weighted avg     0.8524    0.8355    0.8355       383
#
#
# Confusion matrix saved to: /kaggle/working/models/mobilenetv3_rice_disease_v1_confusion_matrix.png
#
# ============================================================
# TEST METRICS
# ============================================================
# Test Accuracy:  0.8355
# Test Precision: 0.8722
# Test Recall:    0.8016
# Test AUC:       0.9769
# Test F1-Score:  0.8354
# ============================================================
#
# ============================================================
# SAVING MODEL AND ARTIFACTS
# ============================================================
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Model saved to: /kaggle/working/models/mobilenetv3_rice_disease_v1_final.keras
# INFO:tensorflow:Assets written to: /kaggle/working/models/mobilenetv3_rice_disease_v1_savedmodel/assets
# INFO:tensorflow:Assets written to: /kaggle/working/models/mobilenetv3_rice_disease_v1_savedmodel/assets
# Saved artifact at '/kaggle/working/models/mobilenetv3_rice_disease_v1_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_176')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   136126817239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817242192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126815623248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817246224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817246608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817248336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817247952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817248144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817245840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817247760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817247568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817249296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817248720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817250448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817250640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817249872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817249488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817249104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817248912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817251600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817251984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817251792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817252752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817253136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817252368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817252944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817253904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817251408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817253520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817250832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817254864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817254288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817251024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817255056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817254480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817255248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817254672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817252560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817254096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817567568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817568912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817569296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817567952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817569104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817569872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817567376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817570640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817571792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817569488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817572560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817572944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817571408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817572752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817573520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817572176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817573328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817571600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817574480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817573904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817574096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817574288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817572368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817575440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817574864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817576208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817575632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817576592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817575056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817573712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817576400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817577168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817575824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817574672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817576976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817575248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817578128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817577552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817577744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817577936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817576016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817579088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817578512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817576784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817579856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817579280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817580240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817578704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817580048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817580816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817579472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817578320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817580624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817578896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817581776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817581200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817581392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817581584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817579664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817582736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817582160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817582352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817581008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817581968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817580432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787388432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787387856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817582544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126817582928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787387472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787388816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787388240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787389776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787387664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787388048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787391504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787390928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787390352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787391696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787392464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787391120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787389968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787392272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787393424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787392848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787393040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787393232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787391312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787394384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787393808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787395152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787394576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787395536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787392656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787395344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787396112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787394768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787393616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787395920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787394192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787397072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787396496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787396688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787396880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787394960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787398032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787397456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787395728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787398800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787398224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787398608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787399568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787397264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787396304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787400144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787398992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787399760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787399952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787398416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787401104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787400912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787399376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787402064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136126787402640: TensorSpec(shape=(), dtype=tf.resource, name=None)
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# SavedModel exported to: /kaggle/working/models/mobilenetv3_rice_disease_v1_savedmodel
# Config saved to: /kaggle/working/models/mobilenetv3_rice_disease_v1_config.json
# Metrics saved to: /kaggle/working/models/mobilenetv3_rice_disease_v1_metrics.json
#
# ============================================================
# TRAINING COMPLETE!
# ============================================================
#
# End Time: 2026-04-28 16:50:58
#
# Training completed successfully!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1_score</td><td>▁</td></tr><tr><td>test_loss</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_accuracy</td><td>▁▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▄▆▆▇▇▇████</td></tr><tr><td>train_auc</td><td>▁▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████▄▇▇███████</td></tr><tr><td>train_loss</td><td>█▅▅▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▇▃▃▂▂▂▁▁▁▁</td></tr><tr><td>+7</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>39</td></tr><tr><td>test_accuracy</td><td>0.83551</td></tr><tr><td>test_auc</td><td>0.97686</td></tr><tr><td>test_f1_score</td><td>0.83537</td></tr><tr><td>test_loss</td><td>0.48776</td></tr><tr><td>test_precision</td><td>0.87216</td></tr><tr><td>test_recall</td><td>0.80157</td></tr><tr><td>timestamp</td><td>2026-04-28T16:50:58....</td></tr><tr><td>train_accuracy</td><td>0.8847</td></tr><tr><td>train_auc</td><td>0.98885</td></tr><tr><td>+8</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mobilenetv3_rice_disease_v1</strong> at: <a href='https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard/runs/lopkd1re' target="_blank">https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard/runs/lopkd1re</a><br> View project at: <a href='https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard' target="_blank">https://wandb.ai/yesayasentosa-politeknik-negeri-batam/karawang-padi-guard</a><br>Synced 5 W&B file(s), 2 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20260428_164322-lopkd1re/logs</code>
